# %%
import asyncio
import requests

from kinopoisk_dev import KinopoiskDev, ReviewField, ReviewParams
from kinopoisk_dev.model import ReviewDocsResponseDto

import pandas as pd

TOKEN = "4593GZG-0GA4AB2-GNTD01T-MQD9ZVX"

# %%
FastTextSocialNetworkModel.MODEL_PATH = 'fasttext-social-network-model.bin'
model = FastTextSocialNetworkModel(tokenizer=tokenizer)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def get_movie_id_by_name(name, page = 1, limit = 1):
    headers = {"X-API-KEY": TOKEN}
    response = requests.get(
        'https://api.kinopoisk.dev/v1.4/movie/search',
        params={
            "query": name,
            "limit": limit,
            "page": page,
        },
        headers=headers
    )
    movie = response.json()
    return movie["docs"][0]['id']

# %%
def get_reviews(movie_id, limit):
    kp = KinopoiskDev(token=TOKEN)
    item = kp.review(
        params=[
            ReviewParams(keys=ReviewField.MOVIE_ID, value=movie_id),
            ReviewParams(keys=ReviewField.PAGE, value=1),
            ReviewParams(keys=ReviewField.LIMIT, value=limit)
        ]
    )
    return item

# %%
movies_250 = list(map(lambda movie: movie.strip(), list(pd.read_csv('kinopoisk-top250.csv')["movie"])[:5]))
movies_250
# Out:
# ['Побег из Шоушенка', 'Зеленая миля', 'Форрест Гамп', 'Список Шиндлера', '1+1']

# %%
reviews = {}

# %%
for movie in movies_250:
    movie_id = get_movie_id_by_name(movie)
    reviews[movie] = get_reviews(movie_id, 5)

# %%
spaCy
Dostoevsky
TextBlob

# %%
from dostoevsky.tokenization import RegexTokenizer
from dostoevsky.models import FastTextSocialNetworkModel

tokenizer = RegexTokenizer()
model = FastTextSocialNetworkModel(tokenizer=tokenizer)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
df = pd.DataFrame({'movie_id' : [], 'movie_name' : [], 
                   'review_id': [], 'review_title' : [], 'review_text' : [], 
                   'positive' : [], 'negative' : [], 'neutral' : [], 
                   'kinopoisk-eval' : [], 'date' : []})

# %%
for movie in movies_250:
    for review in reviews[movie].docs:
        text = review.review
        results = model.predict([text], k=5)[0]
        new_line = [review.movieId, movie, 
                    review.id, review.title, review.review, 
                    results['positive'], results['negative'], results['neutral'], 
                    review.type, review.date]
        df.loc[len(df.index)] = new_line

# %%
df.head()
# Out:
#    movie_id         movie_name  review_id  \
# 0       326  Побег из Шоушенка    3301672
# 1       326  Побег из Шоушенка    3304191
# 2       326  Побег из Шоушенка    3324223
# 3       326  Побег из Шоушенка    3289333
# 4       326  Побег из Шоушенка    3274753
#
#                                        review_title  \
# 0                                      НЕправосудие
# 1                                     Жажда свободы
# 2  Главным героем всё это время был не Энди Дюфрейн
# 3                               Свобода, она такая.
# 4                            Околозаконное рабство.
#
#                                          review_text  positive  negative  \
# 0  Как часто люди сталкиваются с правосудием? Как...  0.164526  0.156115
# 1  'Побег из Шоушенка' – фильм о классической ист...  0.201823  0.156115
# 2  Говоря про фильм «Побег из Шоушенка», то я все...  0.136618  0.217348
# 3  Неразлучная парочка 'рабство-свобода' привлека...  0.156115  0.217348
# 4  Да-да, 'Зелёная миля', 'Побег из Шоушенка' и '...  0.245095  0.228166
#
#     neutral kinopoisk-eval                      date
# 0  0.430157     Позитивный  2023-09-24T16:47:42.000Z
# 1  0.392347     Позитивный  2023-10-02T12:35:24.000Z
# 2  0.422515     Позитивный  2023-11-27T14:03:07.000Z
# 3  0.453272    Нейтральный  2023-08-19T10:55:13.000Z
# 4  0.287778     Позитивный  2023-07-03T12:53:45.000Z

# %%
df.to_csv('movies.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection = '3d')

x = df['positive']
y = df['negative']
z = df['neutral']

ax.set_xlabel("positive")
ax.set_ylabel("negative")
ax.set_zlabel("neutral")

colors = list(map(lambda x: movies_250.index(x)+1, np.array(df['movie_name'])))

scatter = ax.scatter3D(x, y, z, s=200, c=colors, cmap='viridis')
legend = ax.legend(*[scatter.legend_elements()[0], movies_250], 
                    title="Legend", loc='upper left')
ax.add_artist(legend)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot()

sns.scatterplot(data=df, x="positive", y="negative", s=200, c=colors, cmap='viridis')
legend = ax.legend(*[scatter.legend_elements()[0], movies_250], 
                    title="Legend", loc='upper left')
ax.add_artist(legend)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
average_values = df.groupby(['movie_name'])[['positive', 'negative', 'neutral']].mean().reset_index()
average_values
# Out:
#           movie_name  positive  negative   neutral
# 0                1+1  0.257298  0.198180  0.385555
# 1       Зеленая миля  0.178120  0.212761  0.350472
# 2  Побег из Шоушенка  0.159423  0.211419  0.405325
# 3    Список Шиндлера  0.142653  0.238236  0.448597
# 4       Форрест Гамп  0.162038  0.228633  0.379799

# %%
plot = average_values.plot(x="movie_name", y=["positive", "negative", "neutral"], kind="bar")
plot.set_title('Тональность отзывов по результатам Dostoevsky', fontdict={'fontsize':15}, pad=12)
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,9)})
plot = sns.countplot(x="movie_name", hue="kinopoisk-eval", data=df)
plot.set_title('Тональность отзывов по оценке кинопоиска', fontdict={'fontsize':15}, pad=12)
plt.show()
